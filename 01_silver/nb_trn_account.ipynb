# %%
df = spark.read.table("bronze_workforce.azure_blob_storage.accounts")
df=df.drop('_file','_line','_modified','_fivetran_synced')
display(df)

# %%
df = df.dropDuplicates()
display(df)

# %%
df.write.format("delta").mode("overwrite").saveAsTable("silver_workforce.azure_blob_storage.accounts")
