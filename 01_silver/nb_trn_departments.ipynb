# %%
# %python
import pyspark.sql.functions as F
# from pyspark.sql.types import IntegerType
df = spark.read.table("bronze_workforce.azure_blob_storage.departments")
display(df)

# %%
# %python
df=df.drop('_file','_line','_modified','_fivetran_synced')

# %%
# %python
df_no_dupes = df.dropDuplicates()

# %%
# %python
display(df)

# %%
# %python
import pyspark.sql.functions as F
df = df.withColumn("department_name", F.upper(df["department_name"]))
display(df)

# %%
# %python
df = df.withColumn("department_id", df["department_id"].cast('int'))
display(df)

# %%
# %python
df.write.format("delta").mode("overwrite").saveAsTable("silver_workforce.azure_blob_storage.departments")
