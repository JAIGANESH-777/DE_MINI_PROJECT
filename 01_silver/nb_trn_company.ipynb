# %%
# %python
import pyspark.sql.functions as F
df = spark.read.table("bronze_workforce.azure_blob_storage.company")
display(df)

# %%
df=df.drop('_file','_line','_modified','_fivetran_synced')

# %%
df.write.format("delta").mode("overwrite").saveAsTable("silver_workforce.azure_blob_storage.company")
